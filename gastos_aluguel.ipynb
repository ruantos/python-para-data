# %% [markdown]
# <a href="https://colab.research.google.com/github/ruantos/python-para-data/blob/main/gastos_aluguel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
URL = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv"

data = pd.read_csv(URL, sep=";")

# %%
data.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# ### Novas colunas com gastos mensais e anuais por imóvel

# %%
data["Valor_por_mes"] = data["Valor"] + data["Condominio"]

# %%
data["Valor_por_ano"] = (data["Valor_por_mes"] * 12) + data['IPTU']

# %% [markdown]
# ## Colunas categóricas

# %%
data["Possui_suite"] = data['Suites'] > 0

# %%
data["Descricao"] = data['Tipo'] + " em " + data['Bairro'] + " com " + str(data['Quartos']) + "quartos" + "e" + str(data['Vagas']) + "vaga(s) de garagem."

# %%
data.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  Possui_suite  \
# 0  1700.0       500.0    60.0         2200.0        26460.0         False
# 1  7000.0         NaN     NaN            NaN            NaN          True
# 2  5200.0      4020.0  1111.0         9220.0       111751.0         False
# 3   800.0       390.0    20.0         1190.0        14300.0         False
# 4   800.0       230.0     NaN         1030.0            NaN         False
#
#                                            Descricao
# ...

# %% [markdown]
# ### Salvando arquivo

# %%
data.to_csv("valor_ano_mes.csv", sep=";", index=False)
