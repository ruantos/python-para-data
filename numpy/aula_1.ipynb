# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/alura-cursos/numpy/dados/apples_ts.csv"

indx_cols = np.arange(1, 88, 1)


array = np.loadtxt(url, delimiter=",",
                   usecols=indx_cols)

# %%
# número de dimensões do array
array.ndim
# Out:
# 2

# %%
# num total de células
array.size
# Out:
# 522

# %%
# num de linhas e colunas
array.shape
# Out:
# (6, 87)

# %%
# retorna a transposta da matriz (troca linhas por colunas)
arr_transposed = array.T
arr_transposed
# Out:
# array([[  1.2013,  79.72  ,  42.67  ,  62.55  ,  48.26  ,  71.25  ],
#        [  2.2013,  81.08  ,  44.37  ,  62.73  ,  51.01  ,  71.35  ],
#        [  3.2013,  79.68  ,  44.73  ,  63.43  ,  50.91  ,  70.9   ],
#        [  4.2013,  79.8   ,  46.75  ,  63.83  ,  53.94  ,  71.92  ],
#        [  5.2013,  80.63  ,      nan,  66.06  ,  61.27  ,  72.91  ],
#        [  6.2013,  80.8   ,  51.59  ,  69.22  ,  65.44  ,  74.39  ],
#        [  7.2013,  80.28  ,  57.8   ,  72.07  ,  56.51  ,  73.1   ],
#        [  8.2013,  78.99  ,  62.14  ,  69.31  ,  53.    ,  70.24  ],
#        [  9.2013,  76.77  ,  56.76  ,  65.18  ,  43.87  ,  69.12  ],
#        [ 10.2013,  76.09  ,  50.85  ,  62.13  ,  42.12  ,  68.98  ],
#        [ 11.2013,  76.36  ,  46.43  ,  64.17  ,  43.98  ,  68.58  ],
#        [ 12.2013,  77.16  ,  46.73  ,  65.5   ,  44.66  ,  69.5   ],
#        [  1.2014,  77.5   ,  45.85  ,  66.85  ,  47.73  ,  70.14  ],
#        [  2.2014,  79.03  ,  49.25  ,  68.38  ,  52.31  ,  70.58  ],
# ...

# %%
datas = np.arange(1, 88, 1)

# %%
moscow = prices[:, 0]
kaliningrad = prices[:, 1]
petersburg = prices[:, 2]
krasnodar = prices[:, 3]
ekaterinburg = prices[:, 4]

# %%
plt.plot(datas, moscow)
plt.plot(datas, kaliningrad)
plt.plot(datas, petersburg)
plt.plot(datas, krasnodar)
plt.plot(datas, ekaterinburg)


plt.xlabel("mês")
plt.ylabel("preço")
plt.title("variação de preços nas cidades")
# Out:
# Text(0.5, 1.0, 'variação de preços nas cidades')

# %%
moscow_y1 = moscow[0:12]
moscow_y2 = moscow[12:24]
moscow_y3 = moscow[24:36]
moscow_y4 = moscow[36:48]

# %%
plt.plot(np.arange(1, 13, 1) ,moscow_y1)
plt.plot(np.arange(1, 13, 1) ,moscow_y2)
plt.plot(np.arange(1, 13, 1) ,moscow_y3)
plt.plot(np.arange(1, 13, 1) ,moscow_y4)

plt.xlabel("mês")
plt.ylabel("preço")
plt.title("variação de preço em cada ano (Moscow)")

# para identificar cada plot
plt.legend(
    ["Ano 1", "Ano 2", "Ano 3", "Ano 4"]
)

# %%
# Checa se dois arrays são iguais. Retorna um bool
np.array_equal(moscow_y1, moscow_y2)
# Out:
# False

# %%
# Checa se a diferença entre dois array é menor ou igual ao rtol
# útil para checar se valores próximos são iguais dentro de um intervalo "3 = 3.01"
np.allclose(moscow_y1, moscow_y2, rtol=0.1)
# Out:
# False

# %%
# Atribui apenas os valores não-nulos
kaliningrad_notnull = kaliningrad[~np.isnan(kaliningrad)]
# Nem sempre é a melhor maneira de lidar com valores NaN

# %%
# lida com NaN transformando-o na média dos seus valores vizinhos
kaliningrad[4] = (kaliningrad[3] + kaliningrad[5]) / 2

# %%
plt.plot(datas, kaliningrad)


plt.xlabel("mês")
plt.ylabel("preço")
plt.title("variação de preço em cada mês (Kaliningrad)")
# Out:
# Text(0.5, 1.0, 'variação de preço em cada mês (Kaliningrad)')

# %%
avg_moscow = np.mean(moscow)
avg_kaliningrad = np.mean(kaliningrad)
np.allclose(avg_moscow, avg_kaliningrad, 0.1)
# Out:
# False

# %% [markdown]
# ## Plot de moscow ordenado a função linear

# %%
x = datas
y = 0.52*x + 80

np.linalg.norm(moscow - y)
# Out:
# np.float64(110.48504740461489)

# %%
plt.plot(datas, moscow)
plt.plot(x, y)

# %% [markdown]
# ## Gerando números aleatórios

# %%
np.random.randint(low=40, high=100, size=100)
# Out:
# array([49, 99, 40, 81, 83, 43, 68, 98, 92, 94, 66, 92, 56, 93, 83, 52, 79,
#        87, 41, 75, 57, 78, 74, 97, 77, 92, 66, 70, 58, 43, 45, 91, 62, 62,
#        75, 71, 98, 77, 43, 45, 76, 84, 59, 52, 91, 52, 84, 82, 77, 64, 69,
#        47, 60, 62, 79, 55, 93, 71, 97, 70, 47, 83, 77, 99, 89, 58, 54, 44,
#        94, 88, 72, 51, 85, 91, 43, 88, 99, 52, 83, 44, 71, 92, 53, 71, 69,
#        75, 50, 86, 53, 74, 65, 63, 47, 91, 93, 61, 75, 66, 69, 97])

# %% [markdown]
# ## Como salvar arquivos com numpy

# %%
np.savetxt("arquivo_csv", datas, delimiter=",")
